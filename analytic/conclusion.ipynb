# %% [markdown]
# Коэффициент наклона графика D(T) - 3.18665e-8

# %%
В данной работе представлена реализация метода пробных частиц для моделирования диффузии легкого газа в плотном.
Метод не моделирует частицы тяжелого газа напрямую, а только разыгрывает вероятностным методом, было ли столкновение легкой частицы с тяжелой.
После чего в случае столкновения меняет скорость частицы, считая столкновение упругим. Фоновый газ в процессе моделирования не меняется.

Результаты модели я сравнивал с законом Эйнштейна: <r**2> = 6Dt и упрощенной формулой Чепмена-Энскога: 
D = 3/(8 * n * sigma) * sqrt(RT / (2 * pi * mu))
n - концентрация фона
sigma - среднее сечение столкновений
mu - приведенная молярная масса
T - температура фона.

Сравним теоретические значения с моделью:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Как видим график <r**2>(t) почти сразу ложится на линию и лишь вначале расходится. Коэффициент наклона деленный на 6 - крэффициент диффузии равен: 3.03e-5 тогда как теоретически получается 3.10e-5. Как видим расход достаточно маленький, что говорит о достаточной
# точности модели.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![график диффузии от обратной концентрации.png](<attachment:график диффузии от обратной концентрации.png>)

# %% [markdown]
# Как видим, график зависимости коэффициента диффузии от концентрации - гиперболический, что вписывается в модель. Лианеризованный график так же ложится на прямую. Коэффициент наклона прямой равен 7.33e+20. Теоретически он равен 3/(8 * sigma) * sqrt(RT / (2 * pi * mu)) =
# = 7.49e+20 что так же близко к полученному нами

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![график зависимости коэффициента диффузии от температуры.png](<attachment:график зависимости коэффициента диффузии от температуры.png>)

# %% [markdown]
# Исследуем зависимость диффузии от температуры. На графике мы видим линеаризованную зависимость D~√T. Коэффициент наклона равен 1.49e-06. Теоретический коэффициент наклона равен 1.7912054402538246e-06. Расхождения уже 16%, но порядок тот же.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Так выглядит скриншот из симуляции движения 10^5 молекул в течении 1000 итераций шагом 1 пикосекунда. Начальная конфигурация - молекулы лежат на квадрате размером 1мкм на 1мкм.

# %% [markdown]
# Итого можно сказать что модель вполне неплохо работает для разреженного газа. Возможные расхождения связаны с неидельностью метода и приблежонностью теоретичесой формулы.
